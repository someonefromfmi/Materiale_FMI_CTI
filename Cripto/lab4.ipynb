# %% [markdown]
# # Lab 4
#
# ## Ex 1
#
# - A 4
# - B 2
# - C 1
# - D 3
# - E 6
# - F 5
#
# ## Ex 2
#
# - titlu vag, menit sa atraga atentia, pentru a forta utilizatorul sa interactioneze cu mail-ul
# - cerere pentru conectarea la cont prin email
# - adresa de mail nu face parte din domeniul companiei
#
# ## Ex 3
#
# - Ce beneficii ați obține dacă atacul ar fi cu succes?
# R: Pot obtine acees la datele persoanle ale utilizatorului, poate chiar la contul bancar la acestuia.
#
# Buna ziua,
# Cosmin Calinov
#
# Am detectat o bresa de securitate in contul dumneavoastra. Acesta a fost folosit pentru a efectua diferite tranzactii ilegale. Ulterior, toate aceste tranzactii au fost sterse, dar este necesara o retrimitere a datelor aferente pentru a va reactiva in siguranta contul (Suma blocata: 2247 lei). Va rugam sa atasati parola si email-ul asociate contului dumneavoastra pentru a va putea debloca contul.
#
# Cu stima,
# Alice Hitchens

# %% [markdown]
# # Email ilegitim
#
# ![imagine](image.png)
#
# ![](image_copy.png)

# %% [markdown]
# # Email legitim
#
# ![](image2.png)
# ![](image3.png)
